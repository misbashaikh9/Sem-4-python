# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Datasets/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       94
# weight          351
# acceleration     95
# model year       13
# origin            3
# car name        305
# dtype: int64

# %%
df.cylinders.unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
pd.plotting.parallel_coordinates(df,'cylinders',cols=['mpg','weight','acceleration','displacement'],
                                 color=['red','blue','pink','orange','black'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pd.plotting.parallel_coordinates(df,'origin',cols=['mpg','weight','acceleration','displacement'],
                                 color=['red','blue','pink','orange','black'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df=pd.read_csv('Datasets/chile.csv')
df
# Out:
#      region  population sex   age education   income  statusquo vote
# 0         N      175000   M  65.0         P  35000.0    1.00820    Y
# 1         N      175000   M  29.0        PS   7500.0   -1.29617    N
# 2         N      175000   F  38.0         P  15000.0    1.23072    Y
# 3         N      175000   F  49.0         P  35000.0   -1.03163    N
# 4         N      175000   F  23.0         S  35000.0   -1.10496    N
# ...     ...         ...  ..   ...       ...      ...        ...  ...
# 2695      M       15000   M  42.0         P  15000.0   -1.26247    N
# 2696      M       15000   F  28.0         P  15000.0    1.32950    Y
# 2697      M       15000   F  44.0         P  75000.0    1.42045    Y
# 2698      M       15000   M  21.0         S  75000.0    0.18315  NaN
# 2699      M       15000   M  20.0        PS  35000.0    1.38179    Y
#
# [2700 rows x 8 columns]

# %%
df1=pd.read_csv('Datasets/chile.csv')
df1
# Out:
#      region  population sex   age education   income  statusquo vote
# 0         N      175000   M  65.0         P  35000.0    1.00820    Y
# 1         N      175000   M  29.0        PS   7500.0   -1.29617    N
# 2         N      175000   F  38.0         P  15000.0    1.23072    Y
# 3         N      175000   F  49.0         P  35000.0   -1.03163    N
# 4         N      175000   F  23.0         S  35000.0   -1.10496    N
# ...     ...         ...  ..   ...       ...      ...        ...  ...
# 2695      M       15000   M  42.0         P  15000.0   -1.26247    N
# 2696      M       15000   F  28.0         P  15000.0    1.32950    Y
# 2697      M       15000   F  44.0         P  75000.0    1.42045    Y
# 2698      M       15000   M  21.0         S  75000.0    0.18315  NaN
# 2699      M       15000   M  20.0        PS  35000.0    1.38179    Y
#
# [2700 rows x 8 columns]

# %%
df.duplicated().sum()
# Out:
# 9

# %%
df=df.drop_duplicates()
df
# Out:
#      region  population sex   age education   income  statusquo vote
# 0         N      175000   M  65.0         P  35000.0    1.00820    Y
# 1         N      175000   M  29.0        PS   7500.0   -1.29617    N
# 2         N      175000   F  38.0         P  15000.0    1.23072    Y
# 3         N      175000   F  49.0         P  35000.0   -1.03163    N
# 4         N      175000   F  23.0         S  35000.0   -1.10496    N
# ...     ...         ...  ..   ...       ...      ...        ...  ...
# 2695      M       15000   M  42.0         P  15000.0   -1.26247    N
# 2696      M       15000   F  28.0         P  15000.0    1.32950    Y
# 2697      M       15000   F  44.0         P  75000.0    1.42045    Y
# 2698      M       15000   M  21.0         S  75000.0    0.18315  NaN
# 2699      M       15000   M  20.0        PS  35000.0    1.38179    Y
#
# [2691 rows x 8 columns]

# %%
df.shape
# Out:
# (2691, 8)

# %%
df.isna().sum()
# Out:
# region          0
# population      0
# sex             0
# age             1
# education      11
# income         98
# statusquo      17
# vote          168
# dtype: int64

# %%
df=df.dropna()
df
# Out:
#      region  population sex   age education   income  statusquo vote
# 0         N      175000   M  65.0         P  35000.0    1.00820    Y
# 1         N      175000   M  29.0        PS   7500.0   -1.29617    N
# 2         N      175000   F  38.0         P  15000.0    1.23072    Y
# 3         N      175000   F  49.0         P  35000.0   -1.03163    N
# 4         N      175000   F  23.0         S  35000.0   -1.10496    N
# ...     ...         ...  ..   ...       ...      ...        ...  ...
# 2694      M       15000   M  42.0         S  35000.0   -0.00233    U
# 2695      M       15000   M  42.0         P  15000.0   -1.26247    N
# 2696      M       15000   F  28.0         P  15000.0    1.32950    Y
# 2697      M       15000   F  44.0         P  75000.0    1.42045    Y
# 2699      M       15000   M  20.0        PS  35000.0    1.38179    Y
#
# [2422 rows x 8 columns]

# %%
pd.crosstab(df['sex'],df['education'])
# Out:
# education    P   PS    S
# sex
# F          551  181  510
# M          450  235  495

# %%
pd.crosstab(df['sex'],df['education'],colnames=['ed'],rownames=['s'])
# Out:
# ed    P   PS    S
# s
# F   551  181  510
# M   450  235  495

# %%
pd.crosstab(df['sex'],df['education'],colnames=['ed'],rownames=['s'],margins=True)
# Out:
# ed      P   PS     S   All
# s
# F     551  181   510  1242
# M     450  235   495  1180
# All  1001  416  1005  2422

# %%
df
# Out:
#      region  population sex   age education   income  statusquo vote
# 0         N      175000   M  65.0         P  35000.0    1.00820    Y
# 1         N      175000   M  29.0        PS   7500.0   -1.29617    N
# 2         N      175000   F  38.0         P  15000.0    1.23072    Y
# 3         N      175000   F  49.0         P  35000.0   -1.03163    N
# 4         N      175000   F  23.0         S  35000.0   -1.10496    N
# ...     ...         ...  ..   ...       ...      ...        ...  ...
# 2694      M       15000   M  42.0         S  35000.0   -0.00233    U
# 2695      M       15000   M  42.0         P  15000.0   -1.26247    N
# 2696      M       15000   F  28.0         P  15000.0    1.32950    Y
# 2697      M       15000   F  44.0         P  75000.0    1.42045    Y
# 2699      M       15000   M  20.0        PS  35000.0    1.38179    Y
#
# [2422 rows x 8 columns]

# %%
pd.crosstab(df['sex'],df['education'],values=df['income'],aggfunc={min,max})
# Out:
#                 max                         min
# education         P        PS         S       P      PS       S
# sex
# F          125000.0  200000.0  200000.0  2500.0  2500.0  2500.0
# M          200000.0  200000.0  200000.0  2500.0  7500.0  2500.0

# %%
#project 
pd.crosstab([df['sex'],df['education']],[df['region'],df['vote']])
# Out:
# region          C              M              N               S              \
# vote            A   N   U   Y  A  N   U   Y   A   N   U   Y   A   N   U   Y
# sex education
# F   P           5  22  38  53  0  3  10  15   6  13  14  45   8  33  43  81
#     PS          1  15   3   8  0  1   1   2   1  10   2  12   3  17   7  13
#     S          17  37  35  35  0  2   3   6   3  17  10  26  12  37  34  42
# M   P           6  48  34  32  1  5   3   6   2  15  11  27   5  35  36  69
#     PS          2  33   3  11  0  0   0   2   5  19   4   8   5  32   3  15
#     S          13  54  17  26  1  6   2   6  12  24   5  14   6  55  17  47
#
# region         SA
# vote            A   N   U   Y
# sex education
# F   P          12  40  62  48
#     PS          8  40  16  21
#     S          21  60  61  52
# M   P           4  47  31  33
#     PS          5  50   7  31
#     S          13  88  39  50

# %%
#9 marker
ip=pd.read_csv('Datasets/ipl-matches.csv')
ip
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ip.nunique()
# Out:
# ID                 950
# City                33
# Date               706
# Season              15
# MatchNumber         80
# Team1               18
# Team2               18
# Venue               49
# TossWinner          18
# TossDecision         2
# SuperOver            2
# WinningTeam         18
# WonBy                4
# Margin              94
# method               1
# Player_of_Match    262
# Team1Players       932
# Team2Players       937
# Umpire1             58
# Umpire2             60
# dtype: int64

# %%
ip.Team1.unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
ip.nunique()
# Out:
# ID                 950
# City                33
# Date               706
# Season              15
# MatchNumber         80
# Team1               14
# Team2               14
# Venue               49
# TossWinner          14
# TossDecision         2
# SuperOver            2
# WinningTeam         14
# WonBy                4
# Margin              94
# method               1
# Player_of_Match    262
# Team1Players       932
# Team2Players       937
# Umpire1             58
# Umpire2             60
# dtype: int64

# %%
oldname={'Delhi Daredevils':'Delhi Capitals',
         'Kings XI Punjab':'Punjab Kings',
         'Rising Pune Supergiants':'Pune Warriors',
         'Gujarat Titans':'Gujarat Lions'}
ip=ip.replace(oldname.keys(),oldname.values())

# %%
ip.Team1.unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Lions', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Rising Pune Supergiant',
#        'Pune Warriors', 'Deccan Chargers', 'Kochi Tuskers Kerala'],
#       dtype=object)

# %%
ip.nunique()
# Out:
# ID                 950
# City                33
# Date               706
# Season              15
# MatchNumber         80
# Team1               14
# Team2               14
# Venue               49
# TossWinner          14
# TossDecision         2
# SuperOver            2
# WinningTeam         14
# WonBy                4
# Margin              94
# method               1
# Player_of_Match    262
# Team1Players       932
# Team2Players       937
# Umpire1             58
# Umpire2             60
# dtype: int64

# %%
teams=ip.Team1.unique()
l=[]
for team in teams:
    played=ip[(ip['Team1']==team) | (ip['Team2']==team)].shape[0]
    win=ip[(ip.WinningTeam ==team)].shape[0]
    Home_win=ip[(ip.WinningTeam ==team) & (ip.Team1==team)].shape[0]
    Home_play=ip[ip.Team1==team].shape[0]
    away_win=ip[(ip.WinningTeam ==team) & (ip.Team2==team)].shape[0]
    away_play=ip[ip.Team2==team].shape[0]
    l.append([team,played,((win/played)*100),(Home_win/Home_play)*100,(away_win/away_play)*100])
x=pd.DataFrame(l)
print(x)
# Out:
#                               0    1          2          3          4
# 0              Rajasthan Royals  192  50.000000  55.056180  45.631068
# 1   Royal Challengers Bangalore  226  48.230088  48.412698  48.000000
# 2           Sunrisers Hyderabad  152  49.342105  52.173913  46.987952
# 3                Delhi Capitals  224  45.982143  46.491228  45.454545
# 4           Chennai Super Kings  208  58.173077  58.558559  57.731959
# 5                 Gujarat Lions   46  54.347826  39.130435  69.565217
# 6          Lucknow Super Giants   15  60.000000  87.500000  28.571429
# 7         Kolkata Knight Riders  223  51.121076  53.333333  49.152542
# 8                  Punjab Kings  218  46.330275  45.454545  47.222222
# 9                Mumbai Indians  231  56.709957  58.035714  55.462185
# 10       Rising Pune Supergiant   16  62.500000  71.428571  55.555556
# 11                Pune Warriors   60  28.333333  26.666667  30.000000
# ...

# %%
teams=ip.Team1.unique()
l=[]
for team in teams:
    season=ip[ip['Season']==2022]
    played=ip[((ip['Team1']==team) | (ip['Team2']==team)) & (ip.Season=='2022')].shape[0]
    win=ip[(ip.WinningTeam==team) & (ip.Season=='2022')].shape[0]
    l.append([team,played,win,win*2])
x=pd.DataFrame(l)
print(x)
ip.sort_values('Season')
# Out:
#                               0   1   2   3
# 0              Rajasthan Royals  17  10  20
# 1   Royal Challengers Bangalore  16   9  18
# 2           Sunrisers Hyderabad  14   6  12
# 3                Delhi Capitals  14   7  14
# 4           Chennai Super Kings  14   4   8
# 5                 Gujarat Lions  16  12  24
# 6          Lucknow Super Giants  15   9  18
# 7         Kolkata Knight Riders  14   6  12
# 8                  Punjab Kings  14   7  14
# 9                Mumbai Indians  14   4   8
# 10       Rising Pune Supergiant   0   0   0
# 11                Pune Warriors   0   0   0
# 12              Deccan Chargers   0   0   0
# 13         Kochi Tuskers Kerala   0   0   0
#           ID        City        Date   Season MatchNumber  \
# 949   335982   Bangalore  2008-04-18  2007/08           1
# 917   336015      Jaipur  2008-05-11  2007/08          33
# 916   336016  Chandigarh  2008-05-12  2007/08          34
# 915   336017     Kolkata  2008-05-13  2007/08          35
# ...

# %%
ip[ip['TossWinner']==ip['WinningTeam']].shape[0]
# Out:
# 489
